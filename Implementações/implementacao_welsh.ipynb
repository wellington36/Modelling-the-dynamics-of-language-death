# %% [markdown]
# # Implementação Welsh

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import pymc3 as pm
from pymc3.ode import DifferentialEquation
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import arviz as az
import theano
from sklearn.metrics import r2_score

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# O Modelo

# %%
def SIR(y, t, p):
    dt = (1 - y[0])*p[0]*p[1]*(y[0])**p[2] + y[0]*p[0]*(1-p[1])*(1-y[0])**p[2]
    return [dt]

# %% [markdown]
# Testando os dados do modelo:

# %%
times = np.array([1951, 1961, 1971, 1981])


# Gerando curvas simuladas
y = odeint(SIR, y0=[0.368], t=times, args=((-0.12, 0.1, 1.3),), rtol=1e-8) # argumentos chutados
# dados (nesse caso ficticios)
yobs = np.array([[0.289], [0.26], [0.189]])

plt.plot(times[1::], yobs, marker='o', linestyle='none')
plt.plot(times, y[:], color='C0', alpha=0.5, label=f'$S(t)$')
plt.legend();

# %% [markdown]
# Definindo o modelo:

# %%
sir_model = DifferentialEquation(
    func=SIR,
    times=np.array([1961, 1971, 1981]),
    n_states=1,
    n_theta=3,
    t0=1951,
)

# %% [markdown]
# Estimação dos parametro (c, s e a):

# %%
with pm.Model() as model4:
    sigma = pm.HalfCauchy('sigma', 1, shape=1)

    # Distribuições a priori (lower liminf, upper limsup)
    R0 = pm.Bound(pm.Normal, lower=1)('R0', 2, 3)
    c = pm.Uniform('c', -2, 0)
    s = pm.Uniform('s', 0, 1)
    a = pm.Uniform('a', 0, 20)
    
    sir_curves = sir_model(y0=[0.368], theta=[c, s, a])

    Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sigma=sigma, observed=yobs)
#    db = pm.backends.HDF5('traces.h5') # Salva as amostras e assim evita de manter tudo na memória
    trace = pm.sample(3000, tune=1500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [a, s, c, R0, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='18000' class='' max='18000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [18000/18000 10:33<00:00 Sampling 4 chains, 6,168 divergences]
#     </div>
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1957204184059D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1959419636265D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.9964545243548D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.9964545243548D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.6928277387258D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.6928277387258D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.4817019468646D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.4817019468646D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.3349013354076D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.3349013354076D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.2328309408009D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952342285883D+04   r2 =  0.2328309408009D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1954463475290D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1959356576166D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.2138239920110D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.2138239920110D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.2138239920110D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.4276479840219D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.4276479840219D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.4276479840219D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.4276479840219D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.4276479840219D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.1069119960055D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952354145741D+04   r2 =  0.1069119960055D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1952354145741D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1952961773636D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1958127209331D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951834918943D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.8014496470187D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.8014496470187D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.5335658576272D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.5335658576272D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.7029734254490D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.7029734254490D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.7029734254490D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.7029734254490D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.1405946850898D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951486978396D+04   r2 =  0.1405946850898D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951486978396D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1969730142715D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1955278630793D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1959672464700D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1967179354177D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1957903399449D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.6029063058081D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.6029063058081D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.6029063058081D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.3014531529040D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.3014531529040D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.3014531529040D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.3014531529040D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.3014531529040D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.7536328822601D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951787858560D+04   r2 =  0.7536328822601D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951787858560D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1953402099886D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.9295885076096D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.7173623319819D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.5505700744120D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.4201432435410D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.3186899989298D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.2402101044097D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.1798540847798D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.1337203714028D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.9868503496683D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952867742017D+04   r2 =  0.7225938024101D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1952867742017D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.8226079145447D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.8226079145447D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.4015490549113D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.4015490549113D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.7840644869366D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.1960161217341D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.1960161217341D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.3827400152911D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1955792044012D+04   r2 =  0.3827400152911D-13
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1955792044012D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.1012546263077D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.1012546263077D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.8302145085686D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.8302145085686D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.6802557456599D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.6802557456599D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.5570031225786D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.5570031225786D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.4557677271714D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951330917037D+04   r2 =  0.4557677271714D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1953365255351D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.8594932098835D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.8594932098835D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.8594932098835D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.8594932098835D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.2148733024709D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.2148733024709D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.2148733024709D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.2148733024709D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.2559974960186D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951696878956D+04   r2 =  0.6399937400465D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951696878956D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.1132062094964D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.1132062094964D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.8487707911154D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.8487707911154D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.6362793587715D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.6362793587715D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.4769164641371D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.4769164641371D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.3574157667013D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952261422415D+04   r2 =  0.3574157667013D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.6248517381047D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.6248517381047D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.6248517381047D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.3124258690523D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.3124258690523D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.3124258690523D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.3124258690523D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.2240388799123D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.5600971997809D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951873820498D+04   r2 =  0.5600971997809D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951873820498D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1956363301329D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1973144124727D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.1033712961225D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.1033712961225D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.8503256002234D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.8503256002234D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.6990453369967D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.6990453369967D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.5743249826593D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.5743249826593D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.4715630848506D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951500050131D+04   r2 =  0.4715630848506D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.5725727052281D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.5725727052281D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.5725727052281D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.5725727052281D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.9984687473684D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.9984687473684D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.9984687473684D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.1996937494737D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.1996937494737D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952533420089D+04   r2 =  0.1996937494737D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1952533420089D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1957678625280D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.1037976629209D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.1037976629209D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.8314017308777D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.8314017308777D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.6655171200205D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.6655171200205D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.5323904910035D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.5323904910035D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.4256198422919D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951635687151D+04   r2 =  0.4256198422919D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.1041062353263D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.1041062353263D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.8347884604248D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.8347884604248D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.6689462144982D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.6689462144982D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.5356963144387D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.5356963144387D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.4287028893503D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951639453581D+04   r2 =  0.4287028893503D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1956302667346D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.9027526965717D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.9027526965717D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.7133710062578D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.7133710062578D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.5627787141590D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.5627787141590D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.4432230911995D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.4432230911995D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.3484626224979D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951388930293D+04   r2 =  0.3484626224979D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.9399599488194D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.9399599488194D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.7220719891765D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.7220719891765D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.5543841949417D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.5543841949417D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.4254011532464D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.4254011532464D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.3262437775144D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1952234980535D+04   r2 =  0.3262437775144D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1954956666338D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951806575394D+04   r2 =  0.1098559943218D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1951806575394D+04   r2 =  0.1098559943218D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
# ...
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.7646390532421D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.6191057530653D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.4996642937511D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.4012991889129D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.3208301941037D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.2552136853511D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.2019663997810D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.1589529119558D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1980105359560D+04   r2 =  0.1243791696946D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1980105359560D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1968932008929D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.1114589508203D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.1114589508203D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.9151125047287D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.9151125047287D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.7507814383633D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.7507814383633D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.6154981035280D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.6154981035280D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.5042068074116D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979090561437D+04   r2 =  0.5042068074116D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.1080904555072D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.1080904555072D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.8952366805285D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.8952366805285D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.7414184907268D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.7414184907268D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.6139935057958D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.6139935057958D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.5084388842022D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977652749958D+04   r2 =  0.5084388842022D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1977041775537D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1973594674021D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1960763040154D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1960551287965D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1959913078531D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1978090604638D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1972328838195D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.1896067166555D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.1896067166555D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.1896067166555D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.1896067166555D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.1896067166555D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.3792134333110D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.3792134333110D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.3792134333110D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.3792134333110D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1976361363900D+04   r2 =  0.3792134333110D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1976361363900D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1958106076495D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.7750158713213D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.7750158713213D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.5225462092516D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.5225462092516D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.3482240618912D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.3482240618912D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.4580829512292D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.4580829512292D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.4580829512292D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979203773880D+04   r2 =  0.4580829512292D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1979203773880D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1964853311254D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1980518736751D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1974346377704D+04   r2 =                  NaN
# Sampling 4 chains for 1_500 tune and 3_000 draw iterations (6_000 + 12_000 draws total) took 634 seconds.
# There were 1684 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6419991283016545, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 1395 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5766888728317938, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 1533 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6019121145354706, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 1556 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.660238630017388, but should be close to 0.8. Try to increase the number of tuning steps.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %% [markdown]
# Dados da estimação dos parametros:

# %%
print(trace)
# Out:
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %%
data = az.InferenceData.extend(trace)
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3301/3669308610.py in <module>
# ----> 1 data = az.InferenceData.extend(trace)
#       2 data
#
# TypeError: extend() missing 1 required positional argument: 'other'

# %% [markdown]
# Posteriori dos parametros

# %%
az.plot_posterior(data, round_to=2, hdi_prob=0.05);

# %% [markdown]
# Modelagem do Welsh

# %%
az.plot_trace(trace);

# %%
y = odeint(SIR, y0=[0.368], t=times, args=((-0.09, 0.27, 3.9),), rtol=1e-8)
y
# Out:
# array([[0.368     ],
#        [0.32203279],
#        [0.27122709],
#        [0.21677252]])

# %%
plt.plot(times[1::], yobs, marker='o', linestyle='none')
plt.plot(times, y[:], color='C0', alpha=0.5, label=f'$S(t)$')
plt.legend()

# %%
r2_score(np.array([[0.368], [0.289], [0.26], [0.189]]), y)
# Out:
# 0.8791684102272458

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Mon Nov 22 2021
#
# Python implementation: CPython
# Python version       : 3.9.7
# IPython version      : 7.29.0
#
# numpy     : 1.21.2
# matplotlib: 3.4.2
# pymc3     : 3.11.4
# theano    : 1.1.2
# arviz     : 0.11.4
#
# Watermark: 2.2.0
