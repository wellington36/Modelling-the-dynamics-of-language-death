# %% [markdown]
# # Implementação Welsh

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import pymc3 as pm
from pymc3.ode import DifferentialEquation
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import arviz as az
import theano
from sklearn.metrics import r2_score

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# O Modelo

# %%
def SIR(y, t, p):
    dt = (1 - y[0])*p[0]*p[1]*(y[0])**p[2] + y[0]*p[0]*(1-p[1])*(1-y[0])**p[2]
    return [dt]

# %% [markdown]
# Testando os dados do modelo:

# %%
times = np.array([1941, 1951, 1961, 1971, 1981])


# Gerando curvas simuladas
y = odeint(SIR, y0=[0.7], t=times, args=((-0.12, 0.1, 1.3),), rtol=1e-8) # argumentos chutados
# dados (nesse caso ficticios)
yobs = np.array([[0.368], [0.289], [0.26], [0.189]])

plt.plot(times[1::], yobs, marker='o', linestyle='none')
plt.plot(times, y[:], color='C0', alpha=0.5, label=f'$S(t)$')
plt.legend();

# %% [markdown]
# Definindo o modelo:

# %%
sir_model = DifferentialEquation(
    func=SIR,
    times=np.array([1951, 1961, 1971, 1981]),
    n_states=1,
    n_theta=3,
    t0=1941,
)

# %% [markdown]
# Estimação dos parametro (c, s e a):

# %%
with pm.Model() as model4:
    sigma = pm.HalfCauchy('sigma', 1, shape=1)

    # Distribuições a priori (lower liminf, upper limsup)
    R0 = pm.Bound(pm.Normal, lower=1)('R0', 2, 3)
    c = pm.Uniform('c', -2, 0)
    s = pm.Uniform('s', 0, 1)
    a = pm.Uniform('a', 0, 6)
    t0 = pm.Uniform('t0', 0, 1)
    
    sir_curves = sir_model(y0=[t0], theta=[c, s, a])

    Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sigma=sigma, observed=yobs)
#    db = pm.backends.HDF5('traces.h5') # Salva as amostras e assim evita de manter tudo na memória
    trace = pm.sample(2000, tune=1000)
# Out:
# /tmp/ipykernel_6063/793812803.py:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(2000, tune=1000)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [t0, a, s, c, R0, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 15:46<00:00 Sampling 4 chains, 4,158 divergences]
#     </div>
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.1080066085644D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.1080066085644D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.8875467362750D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.8875467362750D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.7393914558668D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.7393914558668D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.7393914558668D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.5745667167357D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.5745667167357D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1945513251568D+04   r2 =  0.4585535273293D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942618561551D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1964386381007D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1959111727193D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1955961009512D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1948608036913D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1973226693494D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1972587562317D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1970654014890D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1955603583594D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.1135120890966D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.1135120890966D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.9361379837472D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.9361379837472D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.9361379837472D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.7579753275723D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.7579753275723D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.6248212213311D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.6248212213311D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963129082586D+04   r2 =  0.6248212213311D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.5653090498345D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.5653090498345D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.5653090498345D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.5653090498345D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.1130618099669D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.1130618099669D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.1130618099669D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.1130618099669D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.1130618099669D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1963471370116D+04   r2 =  0.1130618099669D-12
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1963471370116D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943212575062D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1947320597750D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1956569479476D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1959679123158D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1979152899575D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943360223263D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1979459754842D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945298254307D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.9355757045014D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.9355757045014D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.6113942092929D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.5066014952318D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.3996520010274D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.3298431925951D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.2677150821343D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.2181297454009D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.1766147937238D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1970980009497D+04   r2 =  0.1425851790778D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1970980009497D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1966373921836D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944407832235D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943426808574D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1946225035384D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945821308844D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942610592836D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.4936403978467D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.4936403978467D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.4936403978467D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.4936403978467D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.9872807956934D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.9872807956934D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.9872807956934D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.9872807956934D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.9872807956934D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941866517504D+04   r2 =  0.9872807956934D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941866517504D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.9305099086281D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.9305099086281D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.7650092180084D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.7650092180084D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.6373958356839D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.6373958356839D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.6373958356839D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.4952253915590D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.4952253915590D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1971050074110D+04   r2 =  0.3949279100113D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1970718098845D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1977659452452D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951000000000D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1950306614579D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.2729600120381D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.2729600120381D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.2729600120381D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.2729600120381D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.2729600120381D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.5459200240763D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.5459200240763D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.5459200240763D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.5459200240763D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1950810992832D+04   r2 =  0.5459200240763D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1950810992832D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.9876440910812D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.9876440910812D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.7565620309156D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.7565620309156D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.5780443694189D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.5780443694189D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.4404737776788D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.4404737776788D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.3347261333981D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979915574657D+04   r2 =  0.3347261333981D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951763587141D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945187855093D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.1023333540654D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.1023333540654D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.1023333540654D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.8153346109277D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.8153346109277D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.8153346109277D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.6495326479158D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.6495326479158D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.6495326479158D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1977342089063D+04   r2 =  0.5173826057239D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.1072358462566D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.8870593252058D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.6983422202423D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.5751056516828D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.4656367005987D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.3782892906124D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.3052909938448D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.2455391199638D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.1964798756611D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1978712888213D+04   r2 =  0.1564708155813D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1978712888213D+04   r2 =                  NaN
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 947 seconds.
# There were 961 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.380213672315139, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 779 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.4184538749362779, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 418 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6473392503826976, but should be close to 0.8. Try to increase the number of tuning steps.
# The chain contains only diverging samples. The model is probably misspecified.
# The acceptance probability does not match the target. It is 0.0, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %% [markdown]
# Dados da estimação dos parametros:

# %%
data = az.from_pymc3(trace=trace)
data
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /home/wellington/.local/lib/python3.9/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %% [markdown]
# Posteriori dos parametros

# %%
az.plot_posterior(data, round_to=2, hdi_prob=0.1);

# %% [markdown]
# Modelagem do Welsh

# %%
az.plot_trace(trace);
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /home/wellington/.local/lib/python3.9/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# Got error No model on context stack. trying to find log_likelihood in translation.

# %%
y = odeint(SIR, y0=[0.44], t=times, args=((-0.26, 0.69, 4.3),), rtol=1e-8)
y
# Out:
# array([[0.44      ],
#        [0.38270918],
#        [0.32568902],
#        [0.26620503],
#        [0.20377668]])

# %%
plt.plot(times[1::], yobs, marker='o', linestyle='none')
plt.plot(times, y[:], color='C0', alpha=0.5, label=f'$S(t)$')
plt.legend()

# %%
r2_score(np.array([[0.368], [0.289], [0.26], [0.189]]), y[1::])
# Out:
# 0.8894515116382864

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: Mon Nov 22 2021
#
# Python implementation: CPython
# Python version       : 3.9.7
# IPython version      : 7.29.0
#
# numpy     : 1.21.2
# matplotlib: 3.4.2
# pymc3     : 3.11.4
# theano    : 1.1.2
# arviz     : 0.11.4
#
# Watermark: 2.2.0
