# %% [markdown]
# # Implementação Welsh

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import pymc3 as pm
from pymc3.ode import DifferentialEquation
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import arviz as az
import theano
from sklearn.metrics import r2_score

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# O Modelo

# %%
def SIR(y, t, p):
    dt = (1 - y[0])*p[0]*p[1]*(y[0])**p[2] + y[0]*p[0]*(1-p[1])*(1-y[0])**p[2]
    return [dt]

# %% [markdown]
# Testando os dados do modelo:

# %%
times = np.array([1941, 1951, 1961, 1971, 1981])


# Gerando curvas simuladas
y = odeint(SIR, y0=[0.7], t=times, args=((-0.12, 0.1, 1.3),), rtol=1e-8) # argumentos chutados
# dados (nesse caso ficticios)
yobs = np.array([[0.368], [0.289], [0.26], [0.189]])

plt.plot(times[1::], yobs, marker='o', linestyle='none')
plt.plot(times, y[:], color='C0', alpha=0.5, label=f'$S(t)$')
plt.legend();

# %% [markdown]
# Definindo o modelo:

# %%
sir_model = DifferentialEquation(
    func=SIR,
    times=np.array([1951, 1961, 1971, 1981]),
    n_states=1,
    n_theta=3,
    t0=1941,
)

# %% [markdown]
# Estimação dos parametro (c, s e a):

# %%
with pm.Model() as model4:
    sigma = pm.HalfCauchy('sigma', 1, shape=1)

    # Distribuições a priori (lower liminf, upper limsup)
    R0 = pm.Bound(pm.Normal, lower=1)('R0', 2, 3)
    c = pm.Uniform('c', -2, 0)
    s = pm.Uniform('s', 0, 1)
    a = pm.Uniform('a', 0, 6)
    t0 = pm.Uniform('t0', 0, 1)
    
    sir_curves = sir_model(y0=[t0], theta=[c, s, a])

    Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sigma=sigma, observed=yobs)
#    db = pm.backends.HDF5('traces.h5') # Salva as amostras e assim evita de manter tudo na memória
    trace = pm.sample(3000, tune=2000)
# Out:
# /tmp/ipykernel_3301/1018580903.py:15: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace = pm.sample(3000, tune=2000)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [t0, a, s, c, R0, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 29:09<00:00 Sampling 4 chains, 4,728 divergences]
#     </div>
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1948629225239D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941005563962D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1955537051001D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.9930195705974D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.7847244155655D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.7847244155655D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.5472018751125D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.5472018751125D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.3303320769381D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.3303320769381D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.2220164802993D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.1694048170157D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1979712630520D+04   r2 =  0.1694048170157D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1979712630520D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1959702550294D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941665797905D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1964461036963D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess accuracy requested (tolerances too small). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942193310392D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.9011645452330D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.9011645452330D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.6735065764671D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.6735065764671D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.5033368284943D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.5033368284943D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.3761444695018D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.3761444695018D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.2810798668641D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941398554275D+04   r2 =  0.2810798668641D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1953469877813D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1956253202945D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1950929850285D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.6814251005258D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.6814251005258D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.6814251005258D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.1018350200445D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.8183731866628D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.2045932966657D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.2045932966657D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.2045932966657D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.2045932966657D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1960048680274D+04   r2 =  0.5114832416642D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1960048680274D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1976775020493D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944895706115D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1966489902157D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942055948470D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.7297991963278D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.7297991963278D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.7297991963278D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.7297991963278D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.3238246664426D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.8095616661064D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.8095616661064D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.8095616661064D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.1146310448008D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1973350335646D+04   r2 =  0.2865776120020D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1973350335646D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944957448582D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1950187820823D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941962331225D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942659544422D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1969734445175D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1947072034543D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1943079628121D+04   r2 =  0.9903762622460D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1943079628121D+04   r2 =  0.9903762622460D-13
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943079628121D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1970028771075D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1976008872626D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1977068938396D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1949890451086D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1970296937102D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942948694702D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1958979249708D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944253696066D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1972034687529D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1950547617015D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.1051057865251D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.8285339743680D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.6495695734675D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.5063517715291D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.3923309529534D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.3020501195096D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.2309775830330D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.1753671319217D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.1321355902340D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1947030361026D+04   r2 =  0.9875762603363D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1947030361026D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942897940546D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942281716619D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942662829565D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944456171282D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945293074993D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942255834111D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1948188285835D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941760697813D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1958128263041D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942984644260D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942596119755D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1963395213192D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1946172334561D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945521520259D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941864984100D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942511197818D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942824722308D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944635750716D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941714813210D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943446233969D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942818830694D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941830740150D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943164103703D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1948822623195D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945670335877D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944563477771D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942267770679D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942889158192D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.8828599804533D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.6687921815490D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.5026047989391D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.3745110467800D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.2765323558358D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.2022002606987D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.1463014630920D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.1041720336562D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.7364413405647D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941166201692D+04   r2 =  0.1038304037076D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941166201692D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941288587627D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.1733538695871D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.1733538695871D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.1733538695871D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.3467077391742D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.3467077391742D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.3467077391742D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.3467077391742D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.3467077391742D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.8667693479356D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941316042174D+04   r2 =  0.8667693479356D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941316042174D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942676597906D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942058468415D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944323490519D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942073027574D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1946882653694D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942375387756D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.8893478493349D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.8893478493349D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.5902231587909D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.5902231587909D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.7737588112075D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.7737588112075D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.7737588112075D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.7737588112075D-14
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.1547517622415D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941551761469D+04   r2 =  0.1547517622415D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.9045466550004D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.9045466550004D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.6984968254439D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.6984968254439D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.5381101275259D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.5381101275259D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.4135496537636D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.4135496537636D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.3170367217408D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941144290817D+04   r2 =  0.3170367217408D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941551761469D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944395588343D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1947872341818D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941929188344D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942358765911D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942220573012D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944405816513D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943573527349D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1961447050501D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1956755543552D+04   r2 =                  NaN
# /usr/lib/python3.9/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.1111016741611D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.1111016741611D-12
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.9189742308347D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.9189742308347D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.9189742308347D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.7222020787978D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.7222020787978D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.5808687358068D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.5808687358068D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1968400724056D+04   r2 =  0.4801954173375D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.9597617269968D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.9597617269968D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.6663255296765D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.6663255296765D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.4578749957774D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.4578749957774D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.3111692240966D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.3111692240966D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.2089610759503D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941113519735D+04   r2 =  0.2089610759503D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941113519735D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951000000000D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1944762099399D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1952329054877D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1972689840577D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.7182369175740D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.7182369175740D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.7182369175740D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.7182369175740D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.4108299048417D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.1027074762104D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.1027074762104D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.1027074762104D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.1204762496437D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1941653955194D+04   r2 =  0.3011906241092D-14
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1941653955194D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1956615897971D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1950544134027D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1952288306897D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1980164564884D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1965234330642D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1951000000000D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1962463007091D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942319916833D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942174638678D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945290572175D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1942860420668D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1945203241316D+04   r2 =                  NaN
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.9785972422029D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.7931754003238D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.6453313597630D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.5217178101078D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.4205169848819D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.3373596612107D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.2694759735162D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.2142279809943D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.1694724240089D-13
#  lsoda--  warning..internal t (=r1) and h (=r2) are
#        such that in the machine, t + h = t on the next step
#        (h = step size). solver will continue anyway
#       in above,  r1 =  0.1969026754995D+04   r2 =  0.1333731820915D-13
#  lsoda--  above warning has been issued i1 times.
#        it will not be issued again for this problem
#       in above message,  i1 =        10
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1969026754995D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1975716740494D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1977923472136D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1943303571004D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1977364666046D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1971455699864D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1966426959880D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1966625134901D+04   r2 =                  NaN
#  lsoda--  at t (=r1), too much accuracy requested
#        for precision of machine..  see tolsf (=r2)
#       in above,  r1 =  0.1960045696127D+04   r2 =                  NaN
# Sampling 4 chains for 2_000 tune and 3_000 draw iterations (8_000 + 12_000 draws total) took 1749 seconds.
# There were 1298 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.37926465792278913, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 1326 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.35135688341861515, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 721 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6107465044863305, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 1383 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.35259016254360676, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %% [markdown]
# Dados da estimação dos parametros:

# %%
data = az.from_pymc3(trace=trace)
data
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /home/wellington/.local/lib/python3.9/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# Inference data with groups:
# 	> posterior
# 	> log_likelihood
# 	> sample_stats
# 	> observed_data

# %% [markdown]
# Posteriori dos parametros

# %%
az.plot_posterior(data, round_to=2, hdi_prob=0.09);

# %% [markdown]
# Modelagem do Welsh

# %%
az.plot_trace(trace);
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /home/wellington/.local/lib/python3.9/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# Got error No model on context stack. trying to find log_likelihood in translation.

# %%
y = odeint(SIR, y0=[0.46], t=times, args=((-0.38, 0.96, 3.3),), rtol=1e-8)
y
# Out:
# array([[0.46      ],
#        [0.34403447],
#        [0.27775191],
#        [0.23325028],
#        [0.20025035]])

# %%
plt.plot(times[1::], yobs, marker='o', linestyle='none')
plt.plot(times, y[:], color='C0', alpha=0.5, label=f'$S(t)$')
plt.legend()

# %%
r2_score(np.array([[0.368], [0.289], [0.26], [0.189]]), y[1::])
# Out:
# 0.9062414413449239

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Last updated: Mon Nov 22 2021
#
# Python implementation: CPython
# Python version       : 3.9.7
# IPython version      : 7.29.0
#
# numpy     : 1.21.2
# matplotlib: 3.4.2
# pymc3     : 3.11.4
# theano    : 1.1.2
# arviz     : 0.11.4
#
# Watermark: 2.2.0
